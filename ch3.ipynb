# %%
# !pip install finterstellar
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting finterstellar
#   Downloading finterstellar-0.1.19-py3-none-any.whl (12 kB)
# Collecting pandas-datareader>=0.10.0
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 5.5 MB/s
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (1.21.6)
# Requirement already satisfied: lxml>=4.2.6 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (4.9.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (2.23.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->finterstellar) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->finterstellar) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.4->finterstellar) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->finterstellar) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->finterstellar) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->finterstellar) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->finterstellar) (1.24.3)
# Installing collected packages: pandas-datareader, finterstellar
#   Attempting uninstall: pandas-datareader
#     Found existing installation: pandas-datareader 0.9.0
#     Uninstalling pandas-datareader-0.9.0:
#       Successfully uninstalled pandas-datareader-0.9.0
# Successfully installed finterstellar-0.1.19 pandas-datareader-0.10.0

# %%
import finterstellar as fs

# %% [raw]
# # 3.4

# %%
symbol = 'MSFT'
df = fs.get_price(symbol, start_date='2020-01-01', end_date='2020-12-31')
fs.draw_chart(df, right=symbol)

# %%
fs.macd(df)
# Out:
# Symbols      MSFT  macd  macd_signal  macd_oscillator
# Date
# 2020-01-02 160.62  0.00         0.00             0.00
# 2020-01-03 158.62 -0.04        -0.02            -0.02
# 2020-01-06 159.03 -0.04        -0.03            -0.01
# 2020-01-07 157.58 -0.10        -0.05            -0.05
# 2020-01-08 160.09 -0.02        -0.04             0.02
# ...           ...   ...          ...              ...
# 2020-12-24 222.75  2.24         1.37             0.87
# 2020-12-28 224.96  2.55         1.61             0.94
# 2020-12-29 224.15  2.69         1.82             0.87
# 2020-12-30 221.68  2.57         1.97             0.60
# 2020-12-31 222.42  2.51         2.08             0.43
#
# [253 rows x 4 columns]

# %%
fs.draw_chart(df, left='MSFT', right=['macd','macd_signal','macd_oscillator'])

# %%
fs.indicator_to_signal(df, factor='macd_oscillator', buy=0, sell=0)
# Out:
# Date
# 2020-01-02    zero
# 2020-01-03    zero
# 2020-01-06    zero
# 2020-01-07    zero
# 2020-01-08     buy
#               ...
# 2020-12-24     buy
# 2020-12-28     buy
# 2020-12-29     buy
# 2020-12-30     buy
# 2020-12-31     buy
# Name: trade, Length: 253, dtype: object

# %%
fs.position(df)
fs.draw_chart(df, right='position_chart', left='macd_oscillator')

# %%
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 23.49%
# Accumulated return: 23.49%
# Average return: 2.15%
# Benchmark return : 38.48%
# Number of trades: 11
# Number of win: 6
# Hit ratio: 54.55%
# Investment period: 1.0yrs
# Sharpe ratio: 0.77
# MDD: -11.28%
# Benchmark MDD: -28.24%

# %% [raw]
# # 3.5

# %%
symbol = 'VZ'
df = fs.get_price(symbol, start_date='2020-01-01', end_date='2020-12-31')
fs.draw_chart(df, right=symbol)

# %%
fs.rsi(df, w=14)
fs.draw_chart(df, left='rsi', right=symbol)

# %%
fs.indicator_to_signal(df, factor='rsi', buy=30, sell=70)
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 7.22%
# Accumulated return: 6.80%
# Average return: 4.17%
# Benchmark return : -2.86%
# Number of trades: 2
# Number of win: 1
# Hit ratio: 50.00%
# Investment period: 0.9yrs
# Sharpe ratio: 0.21
# MDD: -17.10%
# Benchmark MDD: -17.73%

# %%
fs.indicator_to_signal(df, factor='rsi', buy=70, sell=50)
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: -2.94%
# Accumulated return: -2.77%
# Average return: -2.77%
# Benchmark return : -2.86%
# Number of trades: 1
# Number of win: 0
# Hit ratio: 0.00%
# Investment period: 0.9yrs
# Sharpe ratio: -1.17
# MDD: -2.90%
# Benchmark MDD: -17.73%

# %%
symbol = 'BA'
df = fs.get_price(symbol, start_date='2021-01-01', end_date='2021-12-31')
fs.draw_chart(df, right=symbol)
fs.envelope(df, w=20, spread=.1)
df.tail()
# Out:
# Symbols        BA  center     ub     lb
# Date
# 2021-12-27 203.17  199.63 219.59 179.67
# 2021-12-28 206.13  200.01 220.01 180.01
# 2021-12-29 203.66  200.30 220.33 180.27
# 2021-12-30 202.71  201.03 221.13 180.93
# 2021-12-31 201.32  200.98 221.07 180.88

# %%
fs.draw_band_chart(df)
fs.band_to_signal(df, buy='A', sell='B')
# Out:
# Date
# 2021-01-04    zero
# 2021-01-05    zero
# 2021-01-06    zero
# 2021-01-07    zero
# 2021-01-08    zero
#               ...
# 2021-12-27    zero
# 2021-12-28    zero
# 2021-12-29    zero
# 2021-12-30    zero
# 2021-12-31    zero
# Name: trade, Length: 252, dtype: object

# %%
fs.position(df)
fs.evaluate(df, cost=.001)
# Out:
# Symbols        BA  center     ub     lb trade position  position_chart  rtn  \
# Date
# 2021-01-04 202.72     NaN    NaN    NaN  zero                        0 1.00
# 2021-01-05 211.63     NaN    NaN    NaN  zero       zz               0 1.00
# 2021-01-06 211.03     NaN    NaN    NaN  zero       zz               0 1.00
# 2021-01-07 212.71     NaN    NaN    NaN  zero       zz               0 1.00
# 2021-01-08 209.90     NaN    NaN    NaN  zero       zz               0 1.00
# ...           ...     ...    ...    ...   ...      ...             ...  ...
# 2021-12-27 203.17  199.63 219.59 179.67  zero       zz               0 1.00
# 2021-12-28 206.13  200.01 220.01 180.01  zero       zz               0 1.00
# 2021-12-29 203.66  200.30 220.33 180.27  zero       zz               0 1.00
# 2021-12-30 202.71  201.03 221.13 180.93  zero       zz               0 1.00
# 2021-12-31 201.32  200.98 221.07 180.88  zero       zz               0 1.00
#
# Symbols     daily_rtn  acc_rtn  acc_rtn_dp  mdd  bm_mdd
# Date
# 2021-01-04       1.00     1.00        0.00 1.00    1.00
# 2021-01-05       1.00     1.00        0.00 1.00    1.00
# 2021-01-06       1.00     1.00        0.00 1.00    1.00
# 2021-01-07       1.00     1.00        0.00 1.00    1.00
# 2021-01-08       1.00     1.00        0.00 1.00    0.99
# ...               ...      ...         ...  ...     ...
# 2021-12-27       1.00     1.04        4.27 0.95    0.75
# 2021-12-28       1.00     1.04        4.27 0.95    0.77
# 2021-12-29       1.00     1.04        4.27 0.95    0.76
# 2021-12-30       1.00     1.04        4.27 0.95    0.75
# 2021-12-31       1.00     1.04        4.27 0.95    0.75
#
# [252 rows x 13 columns]

# %%
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 4.68%
# Accumulated return: 4.27%
# Average return: 4.27%
# Benchmark return : 2.80%
# Number of trades: 1
# Number of win: 1
# Hit ratio: 100.00%
# Investment period: 0.9yrs
# Sharpe ratio: 0.31
# MDD: -5.19%
# Benchmark MDD: -30.09%

# %%
fs.band_to_signal(df, buy='D', sell='B')
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 21.55%
# Accumulated return: 19.66%
# Average return: 9.41%
# Benchmark return : 2.80%
# Number of trades: 2
# Number of win: 2
# Hit ratio: 100.00%
# Investment period: 0.9yrs
# Sharpe ratio: 1.17
# MDD: -10.69%
# Benchmark MDD: -30.09%

# %%
symbol = 'TSM'
df = fs.get_price(symbol, start_date='2020-01-01', end_date='2022-08-25')
fs.draw_chart(df, right=symbol)

# %%
fs.bollinger(df, w=20, k=2)
df.tail()
# Out:
# Symbols      TSM  center  sigma    ub    lb
# Date
# 2022-08-19 87.20   88.09   1.88 91.86 84.33
# 2022-08-22 85.24   88.04   1.95 91.94 84.14
# 2022-08-23 86.03   88.12   1.82 91.77 84.48
# 2022-08-24 85.56   88.02   1.91 91.84 84.20
# 2022-08-25 87.57   87.97   1.91 91.78 84.16

# %%
fs.draw_band_chart(df)
print(df.tail)
# Out:
# <bound method NDFrame.tail of Symbols      TSM  center  sigma    ub    lb trade position  position_chart  \
# Date
# 2020-01-30 55.80   58.19   1.29 60.78 55.61  zero                        0
# 2020-01-31 53.94   57.89   1.53 60.95 54.83  zero       zz               0
# 2020-02-03 54.77   57.72   1.68 61.09 54.36  zero       zz               0
# 2020-02-04 57.52   57.73   1.68 61.09 54.37  zero       zz               0
# 2020-02-05 57.92   57.71   1.68 61.06 54.36  zero       zz               0
# ...          ...     ...    ...   ...   ...   ...      ...             ...
# 2022-08-19 87.20   88.09   1.88 91.86 84.33  zero       zz               0
# 2022-08-22 85.24   88.04   1.95 91.94 84.14  zero       zz               0
# 2022-08-23 86.03   88.12   1.82 91.77 84.48  zero       zz               0
# 2022-08-24 85.56   88.02   1.91 91.84 84.20  zero       zz               0
# 2022-08-25 87.57   87.97   1.91 91.78 84.16  zero       zz               0
#
# Symbols     rtn  daily_rtn  acc_rtn  acc_rtn_dp  mdd  bm_mdd  exs_rtn_daily
# Date
# 2020-01-30 1.00       1.00     1.00        0.00 1.00    1.00          -0.00
# 2020-01-31 1.00       1.00     1.00        0.00 1.00    0.97          -0.00
# 2020-02-03 1.00       1.00     1.00        0.00 1.00    0.98          -0.00
# 2020-02-04 1.00       1.00     1.00        0.00 1.00    1.00          -0.00
# 2020-02-05 1.00       1.00     1.00        0.00 1.00    1.00          -0.00
# ...         ...        ...      ...         ...  ...     ...            ...
# 2022-08-19 1.00       1.00     1.08        7.82 0.87    0.62          -0.00
# 2022-08-22 1.00       1.00     1.08        7.82 0.87    0.61          -0.00
# 2022-08-23 1.00       1.00     1.08        7.82 0.87    0.61          -0.00
# 2022-08-24 1.00       1.00     1.08        7.82 0.87    0.61          -0.00
# 2022-08-25 1.00       1.00     1.08        7.82 0.87    0.62          -0.00
#
# [649 rows x 15 columns]>

# %%
fs.band_to_signal(df, buy='A', sell='C')
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 3.56%
# Accumulated return: 9.41%
# Average return: 1.84%
# Benchmark return : 56.94%
# Number of trades: 12
# Number of win: 2
# Hit ratio: 16.67%
# Investment period: 2.6yrs
# Sharpe ratio: 0.10
# MDD: -38.52%
# Benchmark MDD: -46.28%

# %%
fs.band_to_signal(df, buy='D', sell='A')
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 10.32%
# Accumulated return: 28.70%
# Average return: 4.01%
# Benchmark return : 56.94%
# Number of trades: 7
# Number of win: 5
# Hit ratio: 71.43%
# Investment period: 2.6yrs
# Sharpe ratio: 0.27
# MDD: -26.40%
# Benchmark MDD: -46.28%

# %%
symbol = 'DAL'
df = fs.get_ohlc(symbol, start_date='2020-01-01', end_date='2022-08-25')
df.tail()
# Out:
#             High   Low  Open  Close       Volume  Adj Close
# Date
# 2022-08-19 34.06 33.06 33.88  33.25 9,860,900.00      33.25
# 2022-08-22 32.50 31.85 32.50  32.38 9,246,500.00      32.38
# 2022-08-23 33.02 32.27 32.39  32.87 7,974,300.00      32.87
# 2022-08-24 33.41 32.67 32.88  33.31 5,742,000.00      33.31
# 2022-08-25 34.16 33.52 33.58  33.99 6,785,000.00      33.99

# %%
fs.stochastic(df, symbol, n=14, m=3, t=3)
# Out:
#              DAL  slow_k  slow_d
# Date
# 2020-01-02 59.04     NaN     NaN
# 2020-01-03 58.06     NaN     NaN
# 2020-01-06 57.66     NaN     NaN
# 2020-01-07 57.61     NaN     NaN
# 2020-01-08 58.85     NaN     NaN
# ...          ...     ...     ...
# 2022-08-19 33.25   62.47   75.18
# 2022-08-22 32.38   42.79   61.22
# 2022-08-23 32.87   27.63   44.30
# 2022-08-24 33.31   25.47   31.96
# 2022-08-25 33.99   39.09   30.73
#
# [668 rows x 3 columns]

# %%
fs.draw_chart(df, left='slow_k', right=symbol)

# %%
fs.indicator_to_signal(df, factor='slow_k', buy=20, sell=80)
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: -9.19%
# Accumulated return: -21.98%
# Average return: 0.37%
# Benchmark return : -40.87%
# Number of trades: 14
# Number of win: 9
# Hit ratio: 64.29%
# Investment period: 2.6yrs
# Sharpe ratio: -0.17
# MDD: -61.71%
# Benchmark MDD: -69.06%

# %%
df['indicator'] = df['slow_k'] - df['slow_d']
df.tail()
# Out:
#              DAL  slow_k  slow_d trade position  position_chart  rtn  \
# Date
# 2022-08-19 33.25   62.47   75.18  zero       zz               0 1.00
# 2022-08-22 32.38   42.79   61.22  zero       zz               0 1.00
# 2022-08-23 32.87   27.63   44.30  zero       zz               0 1.00
# 2022-08-24 33.31   25.47   31.96  zero       zz               0 1.00
# 2022-08-25 33.99   39.09   30.73  zero       zz               0 1.00
#
#             daily_rtn  acc_rtn  acc_rtn_dp  mdd  bm_mdd  exs_rtn_daily  \
# Date
# 2022-08-19       1.00     0.78      -21.98 0.74    0.54          -0.00
# 2022-08-22       1.00     0.78      -21.98 0.74    0.52          -0.00
# 2022-08-23       1.00     0.78      -21.98 0.74    0.53          -0.00
# 2022-08-24       1.00     0.78      -21.98 0.74    0.54          -0.00
# 2022-08-25       1.00     0.78      -21.98 0.74    0.55          -0.00
#
#             indicator
# Date
# 2022-08-19     -12.71
# 2022-08-22     -18.43
# 2022-08-23     -16.67
# 2022-08-24      -6.49
# 2022-08-25       8.36

# %%
fs.indicator_to_signal(df, factor='indicator', buy=0, sell=0)
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 3.74%
# Accumulated return: 9.91%
# Average return: 0.52%
# Benchmark return : -40.87%
# Number of trades: 77
# Number of win: 30
# Hit ratio: 38.96%
# Investment period: 2.6yrs
# Sharpe ratio: 0.05
# MDD: -53.57%
# Benchmark MDD: -67.73%

# %% [raw]
# # 3.7

# %%
symbol = 'BA'
df = fs.get_price(symbol, start_date='2020-01-01', end_date='2020-12-31')
fs.draw_chart(df, right=symbol)

# %%
fs.envelope(df, w=20, spread=.1)
df.tail()
# Out:
#                BA  center     ub     lb
# 2020-12-24 217.15  225.27 247.80 202.75
# 2020-12-28 216.09  225.25 247.78 202.73
# 2020-12-29 216.25  225.53 248.08 202.98
# 2020-12-30 216.67  225.71 248.28 203.14
# 2020-12-31 214.06  225.22 247.74 202.70

# %%
fs.draw_band_chart(df)

# %%
fs.band_to_signal(df, buy='A', sell='B')
# Out:
# 2020-01-02    zero
# 2020-01-03    zero
# 2020-01-06    zero
# 2020-01-07    zero
# 2020-01-08    zero
#               ...
# 2020-12-24    zero
# 2020-12-28    zero
# 2020-12-29    zero
# 2020-12-30    zero
# 2020-12-31    zero
# Name: trade, Length: 253, dtype: object

# %%
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 38.38%
# Accumulated return: 35.33%
# Average return: 5.58%
# Benchmark return : -33.79%
# Number of trades: 6
# Number of win: 4
# Hit ratio: 66.67%
# Investment period: 0.9yrs
# Sharpe ratio: 0.88
# MDD: -26.49%
# Benchmark MDD: -72.66%

# %%
fs.band_to_signal(df, buy='D', sell='B')
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: -22.11%
# Accumulated return: -20.35%
# Average return: -0.36%
# Benchmark return : -33.79%
# Number of trades: 4
# Number of win: 3
# Hit ratio: 75.00%
# Investment period: 0.9yrs
# Sharpe ratio: -0.27
# MDD: -67.16%
# Benchmark MDD: -72.66%

# %% [raw]
# # 3.9

# %%
symbol = 'TSM'
df = fs.get_price(symbol, start_date='2020-01-01', end_date='2020-12-31')
fs.draw_chart(df, right=symbol)

# %%
fs.bollinger(df, w=20, k=2)
df.tail()
# Out:
#               TSM  center  sigma     ub     lb
# 2020-12-24 105.97  103.23   2.62 108.48  97.98
# 2020-12-28 106.15  103.60   2.48 108.55  98.65
# 2020-12-29 105.56  104.03   1.96 107.96 100.10
# 2020-12-30 108.90  104.43   2.10 108.63 100.23
# 2020-12-31 109.04  104.91   2.01 108.92 100.89

# %%
fs.draw_band_chart(df)

# %%
fs.band_to_signal(df, buy='A', sell='B')
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 9.12%
# Accumulated return: 8.40%
# Average return: 0.86%
# Benchmark return : 95.41%
# Number of trades: 11
# Number of win: 5
# Hit ratio: 45.45%
# Investment period: 0.9yrs
# Sharpe ratio: 0.32
# MDD: -13.76%
# Benchmark MDD: -27.24%

# %%
fs.band_to_signal(df, buy='D', sell='B')
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 15.37%
# Accumulated return: 14.15%
# Average return: 4.53%
# Benchmark return : 95.41%
# Number of trades: 3
# Number of win: 3
# Hit ratio: 100.00%
# Investment period: 0.9yrs
# Sharpe ratio: 0.46
# MDD: -15.97%
# Benchmark MDD: -26.40%

# %%
df = fs.get_price(symbol, start_date='2020-01-01', end_date='2020-12-31')
fs.bollinger(df, w=20, k=1)
fs.draw_band_chart(df)

# %%
fs.band_to_signal(df, buy='A', sell='B')
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 21.69%
# Accumulated return: 19.97%
# Average return: 1.27%
# Benchmark return : 95.41%
# Number of trades: 20
# Number of win: 5
# Hit ratio: 25.00%
# Investment period: 0.9yrs
# Sharpe ratio: 0.60
# MDD: -14.60%
# Benchmark MDD: -27.24%

# %%
fs.band_to_signal(df, buy='D', sell='B')
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 35.70%
# Accumulated return: 32.86%
# Average return: 2.75%
# Benchmark return : 95.41%
# Number of trades: 8
# Number of win: 7
# Hit ratio: 87.50%
# Investment period: 0.9yrs
# Sharpe ratio: 0.96
# MDD: -19.48%
# Benchmark MDD: -26.40%

# %%
df = fs.get_price(symbol, start_date='2020-01-01', end_date='2020-12-31')
df = fs.bollinger(df, w=20, k=1)
df['s1'] = fs.band_to_signal(df, buy='A', sell='B')
df['s2'] = fs.band_to_signal(df, buy='D', sell='B')

# %%
fs.combine_signal_or(df, 's1', 's2')
# Out:
#               TSM  center     ub     lb trade    s1    s2
# 2020-01-02  60.04     nan    nan    nan  zero  zero  zero
# 2020-01-03  58.06     nan    nan    nan  zero  zero  zero
# 2020-01-06  57.39     nan    nan    nan  zero  zero  zero
# 2020-01-07  58.32     nan    nan    nan  zero  zero  zero
# 2020-01-08  58.75     nan    nan    nan  zero  zero  zero
# ...           ...     ...    ...    ...   ...   ...   ...
# 2020-12-24 105.97  103.23 105.86 100.61   buy   buy  zero
# 2020-12-28 106.15  103.60 106.08 101.13   buy   buy  zero
# 2020-12-29 105.56  104.03 105.99 102.07  zero  zero  zero
# 2020-12-30 108.90  104.43 106.53 102.33   buy   buy  zero
# 2020-12-31 109.04  104.91 106.91 102.90   buy   buy  zero
#
# [253 rows x 7 columns]

# %%
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: 52.29%
# Accumulated return: 48.14%
# Average return: 1.69%
# Benchmark return : 95.41%
# Number of trades: 28
# Number of win: 12
# Hit ratio: 42.86%
# Investment period: 0.9yrs
# Sharpe ratio: 1.03
# MDD: -20.23%
# Benchmark MDD: -27.24%

# %% [raw]
# # 3.10

# %%
symbol = 'DAL'
df = fs.get_ohlc(symbol, start_date='2020-01-01', end_date='2020-12-31')
df.tail()
# Out:
#             High   Low  Open  Close    Volume  Adj Close
# 2020-12-24 40.44 39.60 40.42  39.73   5176400      39.73
# 2020-12-28 40.78 40.01 40.27  40.15  10654400      40.15
# 2020-12-29 40.84 39.90 40.84  40.03   8142800      40.03
# 2020-12-30 40.91 39.89 40.00  40.56   8504600      40.56
# 2020-12-31 40.74 39.76 40.30  40.21   8705700      40.21

# %%
fs.stochastic(df, symbol, n=14, m=3, t=3)
# Out:
#              DAL  slow_k  slow_d
# 2020-01-02 59.04     nan     nan
# 2020-01-03 58.06     nan     nan
# 2020-01-06 57.66     nan     nan
# 2020-01-07 57.61     nan     nan
# 2020-01-08 58.85     nan     nan
# ...          ...     ...     ...
# 2020-12-24 39.73   17.11   18.44
# 2020-12-28 40.15   25.84   20.44
# 2020-12-29 40.03   24.35   22.43
# 2020-12-30 40.56   32.62   27.60
# 2020-12-31 40.21   35.93   30.97
#
# [253 rows x 3 columns]

# %%
fs.draw_chart(df, left='slow_k', right=symbol)

# %%
fs.indicator_to_signal(df, factor='slow_k', buy=20, sell=80)
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: -30.16%
# Accumulated return: -27.93%
# Average return: -1.64%
# Benchmark return : -30.05%
# Number of trades: 6
# Number of win: 4
# Hit ratio: 66.67%
# Investment period: 0.9yrs
# Sharpe ratio: -0.37
# MDD: -61.71%
# Benchmark MDD: -69.06%

# %%
df = fs.get_ohlc(symbol, start_date='2020-01-01', end_date='2020-12-31')
fs.stochastic(df, symbol, n=14, m=3, t=3)
df.tail()
# Out:
#              DAL  slow_k  slow_d
# 2020-12-24 39.73   17.11   18.44
# 2020-12-28 40.15   25.84   20.44
# 2020-12-29 40.03   24.35   22.43
# 2020-12-30 40.56   32.62   27.60
# 2020-12-31 40.21   35.93   30.97

# %%
df['indicator'] = df['slow_k'] - df['slow_d']
df.tail()
# Out:
#              DAL  slow_k  slow_d  indicator
# 2020-12-24 39.73   17.11   18.44      -1.33
# 2020-12-28 40.15   25.84   20.44       5.40
# 2020-12-29 40.03   24.35   22.43       1.92
# 2020-12-30 40.56   32.62   27.60       5.02
# 2020-12-31 40.21   35.93   30.97       4.96

# %%
fs.indicator_to_signal(df, factor='indicator', buy=0, sell=0)
fs.position(df)
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.01)
fs.draw_trade_results(df)
# Out:
# CAGR: -2.96%
# Accumulated return: -2.74%
# Average return: 0.69%
# Benchmark return : -30.05%
# Number of trades: 29
# Number of win: 11
# Hit ratio: 37.93%
# Investment period: 0.9yrs
# Sharpe ratio: -0.06
# MDD: -53.57%
# Benchmark MDD: -69.06%
